# %%
import pandas as pd
import numpy as nd
df =pd.read_csv(r"Titanic_test.csv")

# %%
print(df)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    str
#  3   Sex          418 non-null    str
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    str
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     str
#  10  Embarked     418 non-null    str
# dtypes: float64(2), int64(4), str(5)
# memory usage: 36.1 KB

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
df.isnull()
# Out:
#      PassengerId  Pclass   Name    Sex    Age  SibSp  Parch  Ticket   Fare  \
# 0          False   False  False  False  False  False  False   False  False
# 1          False   False  False  False  False  False  False   False  False
# 2          False   False  False  False  False  False  False   False  False
# 3          False   False  False  False  False  False  False   False  False
# 4          False   False  False  False  False  False  False   False  False
# ..           ...     ...    ...    ...    ...    ...    ...     ...    ...
# 413        False   False  False  False   True  False  False   False  False
# 414        False   False  False  False  False  False  False   False  False
# 415        False   False  False  False  False  False  False   False  False
# 416        False   False  False  False   True  False  False   False  False
# 417        False   False  False  False   True  False  False   False  False
#
#      Cabin  Embarked
# 0     True     False
# 1     True     False
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.fillna(0)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
print(df.dtypes)
# Out:
# PassengerId      int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %%
df["Pclass"]=df["Pclass"].fillna(df["Pclass"].mean())
print(df)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df["Pclass"]=df["Pclass"].fillna(df["Pclass"].median())
print(df)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Length: 418, dtype: bool

# %%
df.sort_values("Pclass")
# Out:
#      PassengerId  Pclass                                             Name  \
# 20           912       1                           Rothschild, Mr. Martin
# 22           914       1             Flegenheim, Mrs. Alfred (Antoinette)
# 23           915       1                  Williams, Mr. Richard Norris II
# 24           916       1  Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 28           920       1                          Brady, Mr. John Bertram
# ..           ...     ...                                              ...
# 19           911       3            Assaf Khalil, Mrs. Mariana (Miriam")"
# 18           910       3                     Ilmakangas, Miss. Ida Livija
# 17           909       3                                Assaf, Mr. Gerios
# 417         1309       3                         Peter, Master. Michael J
# 0            892       3                                 Kelly, Mr. James
#
#         Sex   Age  SibSp  Parch            Ticket      Fare            Cabin  \
# ...

# %%
df.sort_values("Pclass",ascending=True)
# Out:
#      PassengerId  Pclass                                             Name  \
# 20           912       1                           Rothschild, Mr. Martin
# 22           914       1             Flegenheim, Mrs. Alfred (Antoinette)
# 23           915       1                  Williams, Mr. Richard Norris II
# 24           916       1  Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 28           920       1                          Brady, Mr. John Bertram
# ..           ...     ...                                              ...
# 19           911       3            Assaf Khalil, Mrs. Mariana (Miriam")"
# 18           910       3                     Ilmakangas, Miss. Ida Livija
# 17           909       3                                Assaf, Mr. Gerios
# 417         1309       3                         Peter, Master. Michael J
# 0            892       3                                 Kelly, Mr. James
#
#         Sex   Age  SibSp  Parch            Ticket      Fare            Cabin  \
# ...

# %%
df.sort_index()
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.sort_index(ascending=False)
# Out:
#      PassengerId  Pclass                                          Name  \
# 417         1309       3                      Peter, Master. Michael J
# 416         1308       3                           Ware, Mr. Frederick
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 413         1305       3                            Spector, Mr. Woolf
# ..           ...     ...                                           ...
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 3            895       3                              Wirz, Mr. Albert
# 2            894       2                     Myles, Mr. Thomas Francis
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 0            892       3                              Kelly, Mr. James
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df[df["Age"]>56]
# Out:
#      PassengerId  Pclass                                               Name  \
# 2            894       2                          Myles, Mr. Thomas Francis
# 13           905       2                               Howard, Mr. Benjamin
# 48           940       1    Bucknell, Mrs. William Robert (Emma Eliza Ward)
# 69           961       1                Fortune, Mrs. Mark (Mary McDougald)
# 81           973       1                                 Straus, Mr. Isidor
# 96           988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 114         1006       1             Straus, Mrs. Isidor (Rosalie Ida Blun)
# 142         1034       1                         Ryerson, Mr. Arthur Larned
# 152         1044       3                                 Storey, Mr. Thomas
# 179         1071       1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# 193         1085       2                                  Lingane, Mr. John
# ...

# %%
df[(df["Age"]>60)&(df["Age"]<80)]
# Out:
#      PassengerId  Pclass                                               Name  \
# 2            894       2                          Myles, Mr. Thomas Francis
# 13           905       2                               Howard, Mr. Benjamin
# 81           973       1                                 Straus, Mr. Isidor
# 96           988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 114         1006       1             Straus, Mrs. Isidor (Rosalie Ida Blun)
# 142         1034       1                         Ryerson, Mr. Arthur Larned
# 152         1044       3                                 Storey, Mr. Thomas
# 179         1071       1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# 193         1085       2                                  Lingane, Mr. John
# 236         1128       1                           Warren, Mr. Frank Manley
# 305         1197       1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
#
# ...

# %%
df[(df["Age"]>60)|(df["Age"]<80)]
# Out:
#      PassengerId  Pclass                                             Name  \
# 0            892       3                                 Kelly, Mr. James
# 1            893       3                 Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                        Myles, Mr. Thomas Francis
# 3            895       3                                 Wirz, Mr. Albert
# 4            896       3     Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                              ...
# 409         1301       3                        Peacock, Miss. Treasteall
# 411         1303       1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412         1304       3                   Henriksson, Miss. Jenny Lovisa
# 414         1306       1                     Oliva y Ocana, Dona. Fermina
# 415         1307       3                     Saether, Mr. Simon Sivertsen
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.head(56)
# Out:
#     PassengerId  Pclass                                               Name  \
# 0           892       3                                   Kelly, Mr. James
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2           894       2                          Myles, Mr. Thomas Francis
# 3           895       3                                   Wirz, Mr. Albert
# 4           896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5           897       3                         Svensson, Mr. Johan Cervin
# 6           898       3                               Connolly, Miss. Kate
# 7           899       2                       Caldwell, Mr. Albert Francis
# 8           900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9           901       3                            Davies, Mr. John Samuel
# 10          902       3                                   Ilieff, Mr. Ylio
# ...

# %%
df.tail(20)
# Out:
#      PassengerId  Pclass                                             Name  \
# 398         1290       3                   Larsson-Rondberg, Mr. Edvard A
# 399         1291       3                         Conlon, Mr. Thomas Henry
# 400         1292       1                          Bonnell, Miss. Caroline
# 401         1293       2                                  Gale, Mr. Harry
# 402         1294       1                   Gibson, Miss. Dorothy Winifred
# 403         1295       1                           Carrau, Mr. Jose Pedro
# 404         1296       1                     Frauenthal, Mr. Isaac Gerald
# 405         1297       2     Nourney, Mr. Alfred (Baron von Drachstedt")"
# 406         1298       2                        Ware, Mr. William Jeffery
# 407         1299       1                       Widener, Mr. George Dunton
# 408         1300       3                  Riordan, Miss. Johanna Hannah""
# 409         1301       3                        Peacock, Miss. Treasteall
# ...

# %%
df.groupby("Pclass")

# %%
groups = df.groupby("Pclass")   # Example
print(groups.groups)
# Out:
# {1: [11, 12, 14, 20, 22, 23, 24, 26, 28, 34, 41, 44, 46, 48, 50, 53, 59, 64, 67, 68, 69, 73, 74, 75, 77, 81, 82, 92, 94, 96, 100, 112, 114, 118, 122, 131, 141, 142, 144, 146, 148, 150, 156, 158, 166, 168, 177, 179, 181, 182, 184, 191, 196, 202, 205, 208, 215, 217, 218, 224, 231, 234, 236, 239, 240, 242, 245, 252, 266, 270, 272, 287, 290, 293, 298, 305, 306, 308, 314, 316, 323, 324, 327, 331, 335, 343, 350, 355, 356, 364, 368, 371, 372, 374, 375, 378, 390, 391, 395, 397, ...], 2: [2, 7, 13, 15, 16, 30, 31, 43, 51, 52, 54, 61, 65, 78, 84, 89, 101, 109, 110, 119, 120, 128, 137, 143, 149, 162, 164, 175, 176, 178, 180, 185, 186, 189, 190, 193, 194, 198, 203, 204, 207, 212, 213, 220, 222, 229, 230, 238, 241, 246, 247, 248, 250, 258, 262, 264, 275, 276, 277, 278, 279, 296, 301, 302, 317, 319, 322, 326, 328, 329, 330, 336, 338, 340, 346, 348, 349, 351, 352, 353, 361, 362, 369, 370, 373, 377, 384, 385, 387, 393, 401, 405, 406], 3: [0, 1, 3, 4, 5, 6, 8, 9, 10, 17, 18, 19, 21, 25, 27, 29, 32, 3
# ...

# %%
df.groupby("Pclass")["PassengerId"].mean()
# Out:
# Pclass
# 1    1098.224299
# 2    1117.935484
# 3    1094.178899
# Name: PassengerId, dtype: float64

# %%
type(groups)
# Out:
# pandas.api.typing.DataFrameGroupBy

# %%
df.groupby("Pclass")["PassengerId"].agg(["sum","mean"])
# Out:
#            sum         mean
# Pclass
# 1       117510  1098.224299
# 2       103968  1117.935484
# 3       238531  1094.178899

# %%
df.shape
# Out:
# (418, 11)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.drop(columns="Cabin")
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Embarked
# ...

# %%
df["Age"]=df["Age"].fillna(df["Age"].mean())
print(df)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  SibSp  Parch              Ticket      Fare Cabin  \
# ...

# %%
df["Fare"]=df["Fare"].fillna(df["Fare"].mean())
print(df)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  SibSp  Parch              Ticket      Fare Cabin  \
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.dropna()
# Out:
#      PassengerId  Pclass                                               Name  \
# 12           904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 26           918       1                       Ostby, Miss. Helene Ragnhild
# 28           920       1                            Brady, Mr. John Bertram
# ..           ...     ...                                                ...
# 404         1296       1                       Frauenthal, Mr. Isaac Gerald
# 405         1297       2       Nourney, Mr. Alfred (Baron von Drachstedt")"
# 407         1299       1                         Widener, Mr. George Dunton
# 411         1303       1    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
#
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.dropna(subset=["Cabin"], inplace=True) #to remove the string null values

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.to_csv("cleaned titanic dataset.csv")
