# %% [markdown]
# An Operating System (OS) is the fundamental software that manages your device's hardware, memory, and apps. It acts as a bridge between you and the machine, allowing everything to function without requiring you to know how to write complex machine code.

# %%
import os

# %%
current_dir = print(os.getcwd())
# Out:
# c:\Users\ishik\Operating system

# %%
import os
#check cureent directory 
current_directory = os.getcwd()

print("Current Directory:")
print(current_directory)
# Out:
# Current Directory:
# c:\Users\ishik\Operating system

# %%
import os
 # to create folder 
os.mkdir("Student")

print("Folder Created Successfully")
# Out:
# Folder Created Successfully

# %%
import os
#to print how many folder are presnt in it 
items = os.listdir()

print(items)
# Out:
# ['basic.ipynb', 'Folder', 'Folder1', 'Student']

# %%
import os
#to rename file  change file name by new name 
os.rename("new.txt","old.txt")

print("File Renamed")
# Out:
# File Renamed

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\ishik\Operating system

# %%
os.listdir(os.getcwd())
# Out:
# ['basic.exe',
#  'Hashing',
#  'list.cpp',
#  'list.exe',
#  'map.cpp',
#  'map.exe',
#  'recursion',
#  'reverse.cpp',
#  'set.cpp',
#  'set.exe',
#  'STL.cpp',
#  'stl.exe',
#  'stlbasic.cpp',
#  'stlbasic.exe',
#  'tempCodeRunnerFile.cpp']

# %%
os.chdir(r"C:\Users\ishik\DSA") #change dire
print(os.getcwd())
# Out:
# C:\Users\ishik\DSA

# %%
path = r"C:\Users\ishik\DSA"   
os.path.isdir(path)
# Out:
# True

# %%
os.path.isfile(r"C:\Users\ishik\java")
# Out:
# False

# %%
path1=r"C:\Users\ishik\Assigment"
path2=r"C:\Users\ishik\jupyter notebook"
os.path.isdir(path1)
# Out:
# True

# %%
os.rmdir()
os.remove()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 os.rmdir()
#       2 os.remove()
#
# TypeError: rmdir() missing required argument 'path' (pos 1)
