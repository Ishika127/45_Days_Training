# %%
#Encapsulation is the process of wrapping data (variables) and methods (functions) into a single unit (class) and restricting direct access to some data.

#Example
class Student:
    def __init__(self, name, marks):
        self.name = name   #punlic 
        self.__marks = marks   # Private variable
        

    def display(self):
        print("Name:", self.name)
        print("Marks:", self.__marks)

s = Student("Ishika", 90)

s.display()
# Out:
# Name: Ishika
# Marks: 90

# %%
class Campany:
    campany_name = "GOOgle"
    campany_address="DElhi"
    __comapny_account= 6732189648264
    def show(self):
        print(self.campany_name)
        print(self.campany_address)
        print(self.__comapny_account)
c =Campany()
c.show()
# Out:
# GOOgle
# DElhi
# 6732189648264

# %%
#polymosrphism
