# %% [markdown]
# File Handling is the process of creating, opening, reading, writing, updating, and closing files. It allows data to be stored permanently on a computer instead of being lost when the program ends.
#
#
# Why filehandling is Need?
# To store data permanently.
# To retrieve saved data whenever required.
# To manage large amounts of information.
# To share data between different program

# %%
#mode of file handling 
# raed , write, append , create 
# file = open("filename.txt", "mode")

f = open("student.txt", "w") # OPEM FILE

f.write("Hello Ishika\n") # wrie something in the file 
f.write("Welcome to Python")

f.close() # close the file it is impotant

# %%
f = open("student.txt","r") 
f.read() # read file conetnt
# Out:
# 'Hello Ishika\nWelcome to Python'

# %%
f = open("student.txt", "r")

print(f.readline())
print(f.readline())

f.close()
# Out:
# Hello Ishika
#
# Welcome to Python

# %%
f = open("student.txt", "r") # mode read 

print(f.readlines())
print(f.readlines())

f.close()
# Out:
# ['Hello Ishika\n', 'Welcome to Python']
# []

# %%
with open("student.txt", "r") as f: # mode read 
    print(f.read())
# Out:
# Hello Ishika
# Welcome to Python

# %%
f =open("student.txt","w") # write mode 
f.write("hello i m ishika mehta")
f.close()
#overwrite the txt

# %%
f = open("ishika.txt","a") #append mode  # if there is not fule exist it cretae the file and wriutteen the content 
f.write("\n Wlecome to file hey ") 
f.write("\nComputer Science Student")

f.close()

# %%
#create mode  file there is file exist it give u erroe else it create the file 
f = open("demo.txt","w")
f.write("hey ishika pishika ")
f.close()
print("File created successfully!")
# Out:
# File created successfully!

# %%
f=open("Demo.txt",'w')
f.write("This is what I want to write in my file.")
f.close()
f=open("Demo.txt",'r')
print(f.read())
f.close()
print()
# writelines() - accept list
lines = ["First line\n", "Second line\n", "Third line\n"]
f=open("Demo.txt",'w')
f.writelines(lines)
f.close()
f=open("Demo.txt",'r')
print(f.read())
f.close()
# Out:
# This is what I want to write in my file.
#
# First line
# Second line
# Third line

# %%
f= open("student.txt","r")
print(f.tell())
f.close()
# Out:
# 0

# %%
f= open("student.txt","r")
f.seek(4)
print(f.tell())
f.close()
# Out:
# 4

# %%
# Mart System - Save Data to File

file = open("mart_data.txt", "a")

n = int (input("Enter number of products: "))

for i in range(n):
    name = input("Enter product name: ")
    price = input("Enter product price: ")
    quantity = input("Enter quantity: ")

    file.write(f"Product: {name}, Price: {price}, Quantity: {quantity}\n")

file.close()

print("Data saved successfully!")

# Read and display file data
file = open("mart_data.txt", "r")

print("\nSaved Products:")
print(file.read())

file.close()
# Out:
# Data saved successfully!
#
# Saved Products:
# Product: ishika, Price: 34500, Quantity: 5
# Product: poataoto, Price: 4000, Quantity: 4
# Product: nenv, Price: 4, Quantity: 3233fdd
# Product: ishfd, Price: 212, Quantity: 323
# Product: uhrvg, Price: 3, Quantity: 322
# Product: vfkf, Price: 3322, Quantity: 233
# Product: vdf  , Price: 2233, Quantity: 233
# Product: jdf , Price: 2133, Quantity: 332
